# %%
import requests
t=requests.get('https://www.linefriends.com.tw/v2/official/SalePageCategory/290103?sortMode=Newest')
print(t.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <title>LINE FRIENDS商城 - LINE FRIENDS商城</title>
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta name="description" content="在LINE FRIENDS商城有很多BROWN 熊大商品可以挑選,快來選購吧!!">
#   <meta name="keywords" content="BROWN 熊大">
#   <meta property="og:title" content="LINE FRIENDS商城 - LINE FRIENDS商城">
#   <meta property="og:type" content="website">
#   <meta property="og:url" content="http://www.linefriends.com.tw/v2/official/SalePageCategory/290103">
#   <meta property="og:description" content="在LINE FRIENDS商城有很多BROWN 熊大商品可以挑選,快來選購吧!!">
#   <meta name="fb:app_id" content="1708824679217309">
#   <!-- Universal Google Analytics -->
#       <script>
#           (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#           (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#           m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# ...
